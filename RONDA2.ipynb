# %% [markdown]
# ## DATOS

# %%
import pandas as pd

# %%
df_excel = pd.read_excel( r'files_for_lab/excel_files/marketing_customer_analysis.xlsx')

# %%
# !pwd
# Out:
# /Users/yun/Documents/IronHack/Week_one/lab-customer-analysis-round-2

# %%
df_excel.head(8)
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
# 5           5  HO81102         NaN              4745.181764      NaN
# 6           6  IW72280  California              5035.035257       No
# 7           7  IH64929  California              4956.247235       No
#
#    coverage             education effective_to_date employmentstatus gender  \
# 0     Basic               College        2011-02-18         Employed      M
# 1     Basic               College        2011-01-18       Unemployed      F
# 2     Basic              Bachelor        2011-02-10         Employed      M
# ...

# %% [markdown]
# ## Estandarizacion encabezados

# %%
df_excel.columns=df_excel.columns.str.lower().str.replace(' ','_')

# %%
pd.DataFrame(df_excel.columns.sort_values())
# Out:
#                                 0
# 0                        coverage
# 1                        customer
# 2         customer_lifetime_value
# 3                       education
# 4               effective_to_date
# 5                employmentstatus
# 6                          gender
# 7                          income
# 8                   location_code
# 9                  marital_status
# 10           monthly_premium_auto
# 11        months_since_last_claim
# 12  months_since_policy_inception
# 13      number_of_open_complaints
# 14             number_of_policies
# 15                         policy
# 16                    policy_type
# 17               renew_offer_type
# 18                       response
# 19                  sales_channel
# 20                          state
# 21             total_claim_amount
# 22                     unnamed:_0
# 23                  vehicle_class
# 24                   vehicle_size
# 25                   vehicle_type

# %%
df_excel.dtypes
# Out:
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# ...

# %% [markdown]
#   # LOS DATOS NUMERICOS SON:
#   customer_lifetime_value ,effective_to_date ,monthly_premium_auto ,
# months_since_last_claim ,months_since_policy_inception ,number_of_open_complaints             number_of_policies, total_claim_amount

# %% [markdown]
# ## DATOS CATEGORICOS SON :
# vehicle_class ,vehicle_size ,vehicle_type ,policy_type , policy ,sales_channel , location_code    marital_status , response,coverage ,education , customer,state

# %% [markdown]
# ## Valores Nan

# %%
df_excel_limp = df_excel.dropna()
df_excel_limp.head(8)
# Out:
#     unnamed:_0 customer       state  customer_lifetime_value response  \
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 10          10  HG93801     Arizona              5154.764074       No
# 13          13  KR82385  California              5454.587929       No
# 16          16  FH51383  California              5326.677654       No
# 17          17  TR26615      Oregon              2497.531509       No
# 18          18  ZC97968  California              2736.352663       No
# 19          19  NJ54277  California              3746.751625      Yes
#
#     coverage             education effective_to_date employmentstatus gender  \
# 2      Basic              Bachelor        2011-02-10         Employed      M
# 3   Extended               College        2011-01-11         Employed      M
# 10  Extended  High School or Below        2011-01-02         Employed      M
# ...

# %%
df_excel.fillna(0, inplace=True)
df_excel
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877           0              6857.519928        0
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# ## Filtrado por Meses ENERO Y FEBRERO

# %%
import pandas as pd
import numpy as np
import datetime

# %%
df_excel['month'] = pd.DatetimeIndex(df_excel['effective_to_date']).month
df_excel['month']
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 10905    1
# 10906    1
# 10907    2
# 10908    2
# 10909    1
# Name: month, Length: 10910, dtype: int64

# %%
df_excel.head(2)
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response coverage  \
# 0           0  DK49336     Arizona              4809.216960       No    Basic
# 1           1  KX64629  California              2228.525238       No    Basic
#
#   education effective_to_date employmentstatus gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# 0                   9  Corporate Auto  Corporate L3            Offer3
# 1                   1   Personal Auto   Personal L3            Offer4
#
#    sales_channel  total_claim_amount  vehicle_class  vehicle_size  \
# 0          Agent          292.800000  Four-Door Car       Medsize
# 1    Call Center          744.924331  Four-Door Car       Medsize
#
#   vehicle_type month
# 0            0     2
# 1            0     1
#
# [2 rows x 27 columns]

# %%
df_excel.month.str.replace( '1','enero')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df_excel.month.str.replace( '1','enero')
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
# ...

# %% [markdown]
# ## FUNCION

# %%
def limpiar (df_excel):
    print(df_excel.shape)
    print(df_excel.select_dypes('number').columns)
    print(df_excel.select_dypes('object').columns)
    print(df_excel.isnull().sum()[df_excel.isnull().sum()>0]/df.shape[0])

# %%
limpiar(df_excel)
# Out:
# (10910, 27)
